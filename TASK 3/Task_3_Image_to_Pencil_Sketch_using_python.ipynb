# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##  `Image to Pencil Sketch using python`
# ### **` Author :- Kanthuri Venkata Sai Charan`**
# ### `Lets Grow More Virtual Internship Programme(LGMVIP)`
# ### `Data Science Intern @ Lets Grow More`
# ### **`Begineer Task 4`**

# %% [markdown]
# ### **We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.**

# %% [markdown]
# ### ` Steps to follow to get a pencil sketch image`
# 1. **Import required libraries**
# 2. **Read image to RBG format**
# 3. **Convert image to Grayscale image**
# 4. **Convert image to inverted Grayscale image**
# 5. **Smoothen the image with inverted grayscale image and using GaussianBlur function**
# 6. **Dividing the grayscale image by the inverted blurry image**

# %% [markdown]
# ###  `Import required libraries`

# %%
import cv2
import  matplotlib.pyplot as plt 
plt.style.use('seaborn')

# %% [markdown]
# ### `Reading image to RGB format`

# %% [markdown]
# **Here while reading the image, the function `cv2.imread()` automatically reads the image and converts the image into RGB format in form of ND-array.So, That from next time image processing will be easy as it is already in array form.**

# %%
image=cv2.imread("C:\\Users\\Dell\\Desktop\\images.jpg")
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8,8),linewidth=6,edgecolor="black")
plt.imshow(image)
plt.axis("off")
plt.title("Original Image")
plt.show()

# %% [markdown]
# ### `Converting original image to Grayscale`

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(8,8),linewidth=6,edgecolor="black")
plt.imshow(gray_image,cmap='gray')
plt.axis("off")
plt.title("Grayscale Image")
# Out:
# Text(0.5, 1.0, 'Grayscale Image')

# %% [markdown]
# ### `Converting Grayscale image to inverted grayscale image`

# %%
inverted_image = cv2.bitwise_not(gray_image)
plt.figure(figsize=(8,8),linewidth=6,edgecolor="black")
plt.imshow(inverted_image,cmap="gray")
plt.axis("off")
plt.title("Inverted Image")
plt.show()

# %% [markdown]
# ### `Smoothing image with GaussianBlur function:-`

# %% [markdown]
# **Image blurring is achieved by convolving the image with a low-pass filter kernel. It is useful for removing noise. It actually removes high frequency content (eg: noise, edges) from the image. So edges are blurred a little bit in this operation (there are also blurring techniques which don't blur the edges). OpenCV provides four main types of blurring techniques.**

# %% [markdown]
# **The function we will use here is `cv2.GaussianBlur()`. We should specify the width and height of the kernel which should be positive and odd. We also should specify the standard deviation in the X and Y directions, sigmaX and sigmaY respectively. If only sigmaX is specified, sigmaY is taken as the same as sigmaX. If both are given as zeros, they are calculated from the kernel size. Gaussian blurring is highly effective in removing Gaussian noise from an image.**

# %%
img_smoothing = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
plt.figure(figsize=(8,8),linewidth=6,edgecolor="black")
plt.imshow(img_smoothing,cmap="gray")
plt.axis("off")
plt.title("Smoothen Image")
plt.show()

# %% [markdown]
# ### `Creating Final Pencil Sketch image`

# %%
final = cv2.divide(gray_image, 255 - img_smoothing, scale=255)
plt.figure(figsize=(8,8),linewidth=6,edgecolor="black")
plt.imshow(final,cmap="gray")
plt.axis("off")
plt.title("Final Sketch Image")
plt.show()

# %% [markdown]
# ### **`Conclusion`**

# %% [markdown]
# ###  Below  shown figure is a comparsion of all the process of converting image the sketch image.

# %%
plt.figure(figsize=(20,20),linewidth=6,edgecolor="black")
plt.subplot(1,5,1) # 1row,5columns,fig1
plt.imshow(image)
plt.axis("off")
plt.title("Original Image")
plt.subplot(1,5,2) # 1 row , 5 col , 2nd fig
plt.imshow(gray_image,cmap="gray")
plt.axis("off")
plt.title("GrayScale Image")
plt.subplot(1,5,3)  # 1 row , 5 col , fig3
plt.imshow(inverted_image,cmap="gray")
plt.axis("off")
plt.title("Inverted Image")
plt.subplot(1,5,4)  # 1 row , 5 col , fig4
plt.imshow(img_smoothing,cmap="gray")
plt.axis("off")
plt.title("Smoothen Image")
plt.subplot(1,5,5)  # 1 row , 5 col , fig5
plt.imshow(final,cmap="gray")
plt.axis("off")
plt.title("Final Sketch Image")
plt.show()

# %% [markdown]
# ##  **`Thank You`**
# ##  **`K V SAI CHARAN`**
